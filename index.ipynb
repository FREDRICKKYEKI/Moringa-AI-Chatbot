# %%
import json
import textwrap

json_file = "moringa_scraper/moringa_text_corpus.json"

with open(json_file, "r") as f:
    json_corpus = json.load(f)

all_text_lists = []

i = 0

for link, text_list in json_corpus.items():
    if "blog" in link or "apply" in link:
        continue
    print(i,link)
    all_text_lists += text_list
    i += 1

# all_text_lists= [text for text in all_text_lists if len(text.split(" ")) > 4]

corpus = "\n".join(all_text_lists)

corpus = textwrap.fill(corpus, width=138)

with open("moringa.txt", "w") as file:
    file.write(corpus)
# Out:
# 0 https://moringaschool.com/
# 1 https://moringaschool.com/courses
# 2 https://moringaschool.com/courses/software-engineering-course-online
# 3 https://moringaschool.com/courses/software-engineering-course-online/#?utm_source=Website&utm_medium=Organic&utm_campaign=none&utm_content=course-prerequisites-section-cta&utm_term=Unknown
# 4 https://moringaschool.com/courses/software-engineering-course
# 5 https://moringaschool.com/courses/software-engineering-mobile
# 6 https://moringaschool.com/courses/part-time-software-engineering
# 7 https://moringaschool.com/courses/data-science-course
# 8 https://moringaschool.com/courses/data-science-full-time-hybrid
# 9 https://moringaschool.com/courses/data-science-course-part-time
# 10 https://moringaschool.com/courses/data-science-course-part-time/#?utm_source=Website&utm_medium=Organic&utm_campaign=none&utm_content=course-prerequisites-section-cta&utm_term=Unknown
# 11 https://moringaschool.com/courses/data-visualization-with-python
# ...

# %%
import os

members = ["FREDRICK", "Peninah", "Kelvin", "Angela", "Samuel", "Dennis", "Mark"]

for member in members:
    directory_name = f"__chunk_{member}__"
    os.makedirs(directory_name, exist_ok=True)

# %%
max_words = len(corpus)
chunk_len = max_words // len(members)

i = 0
j = i + chunk_len

for member in members:
    directory_name = f"__chunk_{member}__"

    with open(f"{directory_name}/chunk.txt", "w") as f:
        f.write(corpus[i:j])
    i += chunk_len
    j = i + chunk_len

# %% [markdown]
# # penny

# %%
Certainly! Here are 10 examples for each tag:

### Mobile_Development_Courses:
```json
{
  "tag": "Mobile_Development_Courses",
  "questions": [
    "What are the key features of the mobile development course at Moringa School?",
    "Can you provide details about the instructors for the mobile development course?",
    "How long does the mobile development course at Moringa School last?",
    "What programming languages are covered in the mobile development curriculum?",
    "Tell me about the hands-on learning opportunities in the mobile development course.",
    "Are there any prerequisites for enrolling in the mobile development program?",
    "What is the structure of the mobile development classes? Is it more theoretical or hands-on?",
    "Can you share success stories of students who have completed the mobile development course?",
    "What is the typical class size for the mobile development program?",
    "Are there any specific projects or assignments in the mobile development course?"
  ],
  "responses": [
    "Explore the comprehensive features of our mobile development course, including...",
    "Meet our experienced instructors who bring real-world expertise to the mobile development class.",
    "Discover the duration and pacing options available for the mobile development program.",
    "Learn about the programming languages, frameworks, and tools covered in the mobile development curriculum.",
    "Immerse yourself in hands-on learning experiences, including practical projects and coding exercises.",
    "Understand the prerequisites and requirements for enrolling in the mobile development course.",
    "Get insights into the balance between theory and hands-on practice in our mobile development classes.",
    "Read about inspiring success stories of students who have successfully completed the mobile development program.",
    "Find out about the typical class size and the level of individualized attention in the mobile development course.",
    "Explore specific projects and assignments that enhance the learning experience in mobile development."
  ]
}
```

### Mobile_Development_Career:
```json
{
  "tag": "Mobile_Development_Career",
  "questions": [
    "What career opportunities are available for mobile app developers?",
    "Can you provide insights into the demand for mobile developers in the industry?",
    "How does the course prepare students for a successful career in mobile development?",
    "Tell me about the support provided for job placement after completing the mobile development course.",
    "Are there any success stories of Moringa School students transitioning into mobile development roles?",
    "What companies or industries actively seek mobile app developers?",
    "Is there ongoing support for career advancement after completing the mobile development program?",
    "Can you share information about networking opportunities for mobile development graduates?",
    "What skills do employers typically look for in mobile app developers?",
    "How does Moringa School stay updated with industry trends to ensure students are prepared for the latest demands in mobile development?"
  ],
  "responses": [
    "Explore the diverse career opportunities awaiting mobile app developers after completing the course.",
    "Gain insights into the industry demand for skilled mobile developers and the growth prospects.",
    "Discover how the course equips students with the skills and knowledge needed for a successful career in mobile development.",
    "Learn about the comprehensive job placement support available to graduates, including resume building and interview preparation.",
    "Be inspired by success stories of Moringa School students who have successfully transitioned into mobile development roles.",
    "Explore the specific companies and industries actively seeking mobile app developers.",
    "Understand the ongoing support and resources available for career advancement post-completion.",
    "Discover networking opportunities provided to mobile development graduates for building connections in the industry.",
    "Learn about the key skills that employers typically look for when hiring mobile app developers.",
    "Find out how Moringa School stays updated with industry trends to ensure students are well-prepared for the latest demands in mobile development."
  ]
}
```

### Data_Science_Courses:
```json
{
  "tag": "Data_Science_Courses",
  "questions": [
    "What does the data science course at Moringa School cover?",
    "Can you provide details about the curriculum and modules in the data science program?",
    "How long is the data science course, and what are the scheduling options?",
    "Tell me about the practical aspects of the data science learning experience.",
    "Are there any prerequisites for enrolling in the data science course?",
    "What technologies and tools are covered in the data science curriculum?",
    "Can you provide information about the instructors in the data science program?",
    "How does the course incorporate real-world applications of data science?",
    "What projects or assignments are part of the data science course?",
    "What is the balance between theoretical concepts and hands-on practice in the data science program?"
  ],
  "responses": [
    "Explore the comprehensive coverage of topics in our data science course, including...",
    "Dive into the details of the curriculum and modules designed to make you proficient in data science.",
    "Discover the duration and scheduling options available for the data science program.",
    "Immerse yourself in practical learning experiences, including hands-on projects and real-world applications of data science.",
    "Understand the prerequisites and requirements for enrolling in the data science course.",
    "Explore the technologies and tools that form an integral part of the data science curriculum.",
    "Learn about the experienced instructors who bring real-world expertise to the data science program.",
    "Discover how the course incorporates real-world applications, ensuring practical relevance in data science.",
    "Explore specific projects and assignments that enhance the learning experience in data science.",
    "Understand the balance between theoretical concepts and hands-on practice, creating a well-rounded data science learning program."
  ]
}
```

### Data_Science_Career:
```json
{
  "tag": "Data_Science_Career",
  "questions": [
    "What career paths can graduates pursue after completing the data science course?",
    "Tell me about the demand for data scientists in the current job market.",
    "How does the course prepare students for a successful career in data science?",
    "Are there any success stories of Moringa School data science graduates?",
    "What support is provided for job placement and career advancement after completing the data science program?",
    "What companies or industries actively seek data scientists?",
    "Can you share information about networking opportunities for data science graduates?",
    "What skills do employers typically look for in data scientists?",
    "Is there ongoing support for career advancement after completing the data science program?",
    "How does Moringa School stay updated with industry trends to ensure students are prepared for the latest demands in data science?"
  ],
  "responses": [
    "Explore the diverse career paths available for data science graduates and the industry demand for their skills.",
    "Gain insights into the current job market trends and opportunities for data scientists.",
    "Discover how the course prepares students with the skills and knowledge needed for a successful career in data science.",
    "Be inspired by success stories of Moringa School data science graduates who have excelled in their careers.",
    "Learn about the comprehensive job placement support available, including networking opportunities and career guidance.",
    "Explore the specific companies and industries actively seeking data scientists.",
    "Discover networking opportunities provided to data science graduates for building connections in the industry.",
    "Learn about the key skills that employers typically look for when hiring data scientists.",
    "Understand the ongoing support and resources available for career advancement post-completion.",
    "Find out how Moringa School stays updated with industry trends to ensure students are well-prepared for the latest demands in data science."
  ]
}
```
